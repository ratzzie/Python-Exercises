# %%
import os.path
open('abc.txt', 'w')
print(os.path.isfile('abc.txt'))
# Out:
# True

# %%
# For 32 bit it will return 32 and for 64 bit it will return 64
import struct
print(struct.calcsize("P") * 8)
# Out:
# 64

# %%
import platform
import os
print(os.name)
print(platform.system())
print(platform.release())
# Out:
# posix
# Linux
# 4.19.104+

# %%
import site; 
print(site.getsitepackages())
# Out:
# ['/srv/conda/envs/notebook/lib/python3.7/site-packages']

# %%
from subprocess import call
call(["ls", "-l"])
# Out:
# 0

# %%
import os
print("Current File Name : ",os.path.realpath(__file__))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3cc7168ea599> in <module>
#       1 import os
# ----> 2 print("Current File Name : ",os.path.realpath(__file__))
#       3
#
# NameError: name '__file__' is not defined

# %%
import multiprocessing
print(multiprocessing.cpu_count())
# Out:
# 8

# %%
n = "246.2458"
print(float(n))
print(int(float(n)))
# Out:
# 246.2458
# 246

# %%
from os import listdir
from os.path import isfile, join
files_list = [f for f in listdir('C:\Windows') if isfile(join('C:\Windows', f))]
print(files_list);
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-0096b4439673> in <module>
#       1 from os import listdir
#       2 from os.path import isfile, join
# ----> 3 files_list = [f for f in listdir('C:\Windows') if isfile(join('C:\Windows', f))]
#       4 print(files_list);
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Windows'

# %%
for i in range(0, 10):
    print('*', end="")
print("\n")
# Out:
# **********
