# %%
d_ft = int(input("Input distance in feet: "))
d_inches = d_ft * 12
d_yards = d_ft / 3.0
d_miles = d_ft / 5280.0

print("The distance in inches is %i inches." % d_inches)
print("The distance in yards is %.2f yards." % d_yards)
print("The distance in miles is %.2f miles." % d_miles)
# Out:
# Input distance in feet:  100
# The distance in inches is 1200 inches.
# The distance in yards is 33.33 yards.
# The distance in miles is 0.02 miles.

# %%
days = int(input("Input days: ")) * 3600 * 24
hours = int(input("Input hours: ")) * 3600
minutes = int(input("Input minutes: ")) * 60
seconds = int(input("Input seconds: "))

time = days + hours + minutes + seconds

print("The  amounts of seconds", time)
# Out:
# Input days:  4
# Input hours:  5
# Input minutes:  10
# Input seconds:  20
# The  amounts of seconds 364220

# %%
def absolute_file_path(path_fname):
        import os
        return os.path.abspath('path_fname')        
print("Absolute file path: ",absolute_file_path("test.txt"))
# Out:
# Absolute file path:  /home/jovyan/demo/path_fname

# %%
import os.path, time
print("Last modified: %s" % time.ctime(os.path.getmtime("test.txt")))
print("Created: %s" % time.ctime(os.path.getctime("test.txt")))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-425837321292> in <module>
#       1 import os.path, time
# ----> 2 print("Last modified: %s" % time.ctime(os.path.getmtime("test.txt")))
#       3 print("Created: %s" % time.ctime(os.path.getctime("test.txt")))
#
# /srv/conda/envs/notebook/lib/python3.7/genericpath.py in getmtime(filename)
#      53 def getmtime(filename):
#      54     """Return the last modification time of a file, reported by os.stat()."""
# ---> 55     return os.stat(filename).st_mtime
#      56
#      57
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %%
time = float(input("Input time in seconds: "))
day = time // (24 * 3600)
time = time % (24 * 3600)
hour = time // 3600
time %= 3600
minutes = time // 60
time %= 60
seconds = time
print("d:h:m:s-> %d:%d:%d:%d" % (day, hour, minutes, seconds))
# Out:
# Input time in seconds:  789456
# d:h:m:s-> 9:3:17:36

# %%
height = float(input("Input your height in meters: "))
weight = float(input("Input your weight in kilogram: "))
print("Your body mass index is: ", round(weight / (height * height), 2))
# Out:
# Input your height in meters:  3.5
# Input your weight in kilogram:  90
# Your body mass index is:  7.35

# %%
kpa = float(input("Input pressure in in kilopascals> "))
psi = kpa / 6.89475729
mmhg = kpa * 760 / 101.325
atm = kpa / 101.325
print("The pressure in pounds per square inch: %.2f psi"  % (psi))
print("The pressure in millimeter of mercury: %.2f mmHg" % (mmhg))
print("Atmosphere pressure: %.2f atm." % (atm))
# Out:
# Input pressure in in kilopascals>  12
# The pressure in pounds per square inch: 1.74 psi
# The pressure in millimeter of mercury: 90.01 mmHg
# Atmosphere pressure: 0.12 atm.

# %%
num = int(input("Input a four digit numbers: "))
x  = num //1000
x1 = (num - x*1000)//100
x2 = (num - x*1000 - x1*100)//10
x3 = num - x*1000 - x1*100 - x2*10
print("The sum of digits in the number is", x+x1+x2+x3)
# Out:
# Input a four digit numbers:  5245
# The sum of digits in the number is 16

# %%
x = int(input("Input first number: "))
y = int(input("Input second number: "))
z = int(input("Input third number: "))

a1 = min(x, y, z)
a3 = max(x, y, z)
a2 = (x + y + z) - a1 - a3
print("Numbers in sorted order: ", a1, a2, a3)
# Out:
# Input first number:  2
# Input second number:  4
# Input third number:  5
# Numbers in sorted order:  2 4 5

# %%
import glob
import os

files = glob.glob("*.txt")
files.sort(key=os.path.getmtime)
print("\n".join(files))
