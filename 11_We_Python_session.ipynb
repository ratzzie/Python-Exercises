# %%
from http.client import HTTPConnection
conn = HTTPConnection("example.com")
conn.request("GET", "/")  
result = conn.getresponse()
# retrieves the entire contents.  
contents = result.read() 
print(contents)
# Out:
# b'<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n    <h1>Example Domain</h1>\n    <p>This domain is for use in illustrative examples in documents. You may use this\n    domain in literature without prior coordination or asking for permission.</p>\n    <p><a href="https://www.iana.org/domains/example">More information...</a></p>\n</div>\n</body>\n</html>\n'

# %%
import subprocess
# file and directory listing
returned_text = subprocess.check_output("dir", shell=True, universal_newlines=True)
print("dir command to list file and directory")
print(returned_text)
# Out:
# dir command to list file and directory
# big.csv        jupyterlab-slides.pdf  markdown_python.md  Untitled.ipynb
# data	       Lorenz.ipynb	      notebooks
# jupyterlab.md  lorenz.py	      TCGA_Data

# %%
import os
print()
print(os.path.basename('/users/system1/student1/homework-1.py'))
print()
# Out:
# homework-1.py

# %%
import os
print("\nEffective group id: ",os.getegid())
print("Effective user id: ",os.geteuid())
print("Real group id: ",os.getgid())
print("List of supplemental group ids: ",os.getgroups())
print()
# Out:
# Effective group id:  0
# Effective user id:  1000
# Real group id:  0
# List of supplemental group ids:  [100]

# %%
import os
print()
print(os.environ)
print()
# Out:
# environ({'GCS_PROXY_PORT': 'tcp://10.15.251.138:80', 'CONDA_SHLVL': '1', 'LC_ALL': 'en_US.UTF-8', 'JUPYTERHUB_CLIENT_ID': 'jupyterhub-user-jupyterlab-jupyterlab-demo-w3rfksux', 'KERNEL_PYTHON_PREFIX': '/srv/conda/envs/notebook', 'APP_BASE': '/srv', 'CONDA_EXE': '/srv/conda/bin/conda', 'PROD_NGINX_INGRESS_CONTROLLER_SERVICE_PORT_HTTPS': '443', 'PROXY_API_PORT': 'tcp://10.15.240.3:8001', 'PROD_NGINX_INGRESS_CONTROLLER_STATS_SERVICE_HOST': '10.15.250.50', 'PROD_CERT_MANAGER_PORT_9402_TCP_PROTO': 'tcp', 'FEDERATION_REDIRECT_PORT': 'tcp://10.15.242.219:80', 'PROD_NGINX_INGRESS_CONTROLLER_STATS_PORT': 'tcp://10.15.250.50:18080', 'PROD_NGINX_INGRESS_CONTROLLER_METRICS_PORT_9913_TCP_ADDR': '10.15.242.50', 'PROD_CERT_MANAGER_PORT': 'tcp://10.15.255.159:9402', 'GPROF': '/srv/conda/envs/notebook/bin/x86_64-conda_cos6-linux-gnu-gprof', 'PROD_PROMETHEUS_SERVER_PORT_80_TCP_PROTO': 'tcp', 'PROXY_API_PORT_8001_TCP_PORT': '8001', 'FEDERATION_REDIRECT_PORT_80_TCP_PROTO': 'tcp', 'JUPYTERHUB_ADMIN_ACCESS': '1', 'PROD_PROMETHEUS_SERVER_SERVICE_HOST': '10.15.244.184', 'LANG': 'en_US.UTF-8', 'GCS_PROXY_PORT_80_TCP_PORT': '80', 'MATOMO_PORT_9000_TCP_PORT': '9000', 'GCS_PROXY_PORT_80_TCP_PROTO': 'tcp', 'PROXY_PATCHES_PORT_80_TCP_PROTO': 'tcp', 'HUB_PORT_8081_TCP_PROTO': 'tcp', 'GXX': '/srv/conda/envs/notebook/bin/x86_64-conda_cos6-linux-gnu-g++', 'HUB_SERVICE_HOST': '10.15.251.161', 'NPM_DIR': '/srv/npm', 'HOSTNAME': 'jupyter-jupyterlab-2djupyterlab-2ddemo-2dw3rfksux', 'PROXY_PATCHES_PORT_80_TCP_PORT': '80', 'PROD_GRAFANA_PORT_80_TCP_PORT': '80', 'MATOMO_PORT': 'tcp://10.15.244.111:9000', 'LD_GOLD': '/srv/conda/envs/notebook/bin/x86_64-conda_cos6-linux-gnu-ld.gold', 'FEDERATION_REDIRECT_PORT_80_TCP_PORT': '80', 'PROD_NGINX_INGRESS_DEFAULT_BACKEND_PORT_80_TCP': 'tcp://10.15.248.80:80', 'PROD_GRAFANA_SERVICE_PORT_SERVICE': '80', 'DEBUG_CPPFLAGS': '-D_DEBUG -D_FORTIFY_SOURCE=2 -Og -isystem /srv/conda/envs/notebook/include', 'PROD_NGINX_INGRESS_CONTROLLER_PORT_80_TCP': 'tcp://10.15.245.211:80', 'DEBUG_CFLAGS': '-march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-all -fno-plt -Og -g -Wall -Wextra -fvar-tracking-assignments -ffunction-sections -pipe -isystem /srv/conda/envs/notebook/include', 'BINDER_PORT': 'tcp://10.15.253.247:80', 'GCC_NM': '/srv/conda/envs/notebook/bin/x86_64-conda_cos6-linux-gnu-gcc-nm', 'GSETTINGS_SCHEMA_DIR_CONDA_BACKUP': '', 'PROXY_PATCHES_PORT_80_TCP': 'tcp://10.15.245.144:80', 'PROD_GRAFANA_PORT_80_TCP_PROTO': 'tcp', 'PROXY_PUBLIC_PORT_80_TCP_ADDR': '10.15.242.199', 'PROXY_PUBLIC_PORT_443_TCP_ADDR': '10.15.242.199', 'CONDA_PREFIX': '/srv/conda/envs/notebook', 'GCC_RANLIB': '/srv/conda/envs/notebook/bin/x86_64-conda_cos6-linux-gnu-gcc-ranlib', 'PROXY_PUBLIC_PORT_80_TCP_PORT': '80', 'CFLAGS': '-march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /srv/conda/envs/notebook/include', 'CONDA_DIR': '/srv/conda', 'PROXY_PATCHES_SERVICE_PORT': '80', 'FEDERATION_REDIRECT_SERVICE_HOST': '10.15.242.219', 'GCC_AR': '/srv/conda/envs/notebook/bin/x86_64-conda_cos6-linux-gnu-gcc-ar', 'REDIRECTOR_PORT_80_TCP_ADDR': '10.15.252.165', 'PROD_NGINX_INGRESS_CONTROLLER_PORT': 'tcp://10.15.245.211:80', 'PROXY_PUBLIC_SERVICE_PORT': '443', 'PROD_CERT_MANAGER_PORT_9402_TCP_ADDR': '10.15.255.159', 'PROD_CERT_MANAGER_PORT_9402_TCP': 'tcp://10.15.255.159:9402', '_CE_M': '', 'PROD_NGINX_INGRESS_CONTROLLER_SERVICE_PORT_HTTP': '80', 'KUBERNETES_PORT_443_TCP_PROTO': 'tcp', 'PROD_NGINX_INGRESS_CONTROLLER_PORT_443_TCP_PROTO': 'tcp', 'JUPYTERHUB_ACTIVITY_URL': 'http://10.15.251.161:8081/hub/api/users/jupyterlab-jupyterlab-demo-w3rfksux/activity', 'PROXY_PUBLIC_SERVICE_HOST': '10.15.242.199', 'CC': '/srv/conda/envs/notebook/bin/x86_64-conda_cos6-linux-gnu-cc', 'KUBERNETES_PORT_443_TCP_ADDR': '10.15.240.1', 'READELF': '/srv/conda/envs/notebook/bin/x86_64-conda_cos6-linux-gnu-readelf', 'HUB_PORT_8081_TCP': 'tcp://10.15.251.161:8081', 'CPU_LIMIT': '1.0', 'USER': 'jovyan', 'JUPYTERHUB_B ...

# %%
import os.path
for path in [ 'test.txt', 'filename', '/user/system/test.txt', '/', '' ]:
    print('"%s" :' % path, os.path.splitext(path))
# Out:
# "test.txt" : ('test', '.txt')
# "filename" : ('filename', '')
# "/user/system/test.txt" : ('/user/system/test', '.txt')
# "/" : ('/', '')
# "" : ('', '')

# %%
import os.path
import time

print('File         :', __file__)
print('Access time  :', time.ctime(os.path.getatime(__file__)))
print('Modified time:', time.ctime(os.path.getmtime(__file__)))
print('Change time  :', time.ctime(os.path.getctime(__file__)))
print('Size         :', os.path.getsize(__file__))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-630a2e584b18> in <module>
#       2 import time
#       3
# ----> 4 print('File         :', __file__)
#       5 print('Access time  :', time.ctime(os.path.getatime(__file__)))
#       6 print('Modified time:', time.ctime(os.path.getmtime(__file__)))
#
# NameError: name '__file__' is not defined

# %%
import os.path

for file in [ __file__, os.path.dirname(__file__), '/', './broken_link']:
    print('File        :', file)
    print('Absolute    :', os.path.isabs(file))
    print('Is File?    :', os.path.isfile(file))
    print('Is Dir?     :', os.path.isdir(file))
    print('Is Link?    :', os.path.islink(file))
    print('Exists?     :', os.path.exists(file))
    print('Link Exists?:', os.path.lexists(file))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d08220674138> in <module>
#       1 import os.path
#       2
# ----> 3 for file in [ __file__, os.path.dirname(__file__), '/', './broken_link']:
#       4     print('File        :', file)
#       5     print('Absolute    :', os.path.isabs(file))
#
# NameError: name '__file__' is not defined

# %%
num = float(input("Input a number: "))
if num > 0:
   print("It is positive number")
elif num == 0:
   print("It is Zero")
else:
   print("It is a negative number")
# Out:
# Input a number:  150
# It is positive number

# %%
num_list = [45, 55, 60, 37, 100, 105, 220]
# use anonymous function to filter
result = list(filter(lambda x: (x % 15 == 0), num_list))
print("Numbers divisible by 15 are",result)
# Out:
# Numbers divisible by 15 are [45, 60, 105]
